# %%
import pandas as pd
import glob

all_files = glob.glob("cleaned/*.csv")

li = []

for filename in all_files:
    li.append(pd.read_csv(filename, index_col=None, header=0))

frame = li[0].append(li[1::], ignore_index=True)

# %%
frame.head
# Out:
# <bound method NDFrame.head of            tripduration            starttime             stoptime  \
# 0                   107                07:48                07:49
# 1                   493                12:41                12:49
# 2                   512                14:27                14:35
# 3                   196                15:07                15:10
# 4                   463                16:19                16:27
# ...                 ...                  ...                  ...
# 345435  0 days 00:23:00  2022-01-31 21:33:00  2022-01-31 21:56:00
# 345436  0 days 00:05:00  2022-01-31 14:30:00  2022-01-31 14:35:00
# 345437  0 days 00:07:00  2022-01-31 02:11:00  2022-01-31 02:18:00
# 345438  0 days 00:06:00  2022-01-31 20:38:00  2022-01-31 20:44:00
# 345439  0 days 00:07:00  2022-01-31 23:48:00  2022-01-31 23:55:00
#
#        start station name  start station latitude  start station longitude  \
# ...

# %%
# Drop first 131877 rows
# by selecting all rows from 4th row onwards
N = 131877
frame = frame.iloc[N: , :]
frame.head()
# Out:
#            tripduration            starttime             stoptime  \
# 263754  0 days 00:31:00  2022-01-31 19:26:00  2022-01-31 19:57:00
# 263755  0 days 00:04:00  2022-01-31 15:41:00  2022-01-31 15:45:00
# 263756  0 days 00:09:00  2022-01-31 15:41:00  2022-01-31 15:50:00
# 263757  0 days 00:28:00  2022-01-31 18:28:00  2022-01-31 18:56:00
# 263758  0 days 00:10:00  2022-01-31 11:55:00  2022-01-31 12:05:00
#
#        start station name  start station latitude  start station longitude  \
# 263754          City Hall               40.717732               -74.043845
# 263755          City Hall               40.717732               -74.043845
# 263756      Montgomery St               40.719420               -74.050990
# 263757      Montgomery St               40.719420               -74.050990
# 263758      Montgomery St               40.719420               -74.050990
#
#        end station name  end station latitude  end station longitude usertype  \
# ...

# %%
## delete "0 days" take minutes and multiply by 60 to get seconds and replace the info, so entire column is by seconds
